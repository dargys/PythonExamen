# %% [markdown]
# # Gap Analysis Plan
# ## TechDist GmbH — ViDA E-Invoicing Preparation
#
# **Author:** *(your name)*
# **Date:** *(hand-in date)*
#
# ---

# %% [markdown]
# ## 1. The Requirement
#
# Under ViDA Pillar 1, cross-border B2B e-invoices submitted for digital reporting must contain the following obligatory fields:
#
# `seller_country`, `buyer_country`, `delivery_country`, `vat_number`, `iban`, `invoice_date`, `currency`, `invoice_type`, `corrective_ref` (for credit notes)
#
# Source: European Commission ViDA Pillar 1 — e-invoicing and real-time digital reporting.

# %% [markdown]
# ## 2. Our Data
#
# TechDist GmbH has provided 5 datasets from their ERP system representing the full transaction flow from customer registration through to invoicing. The tables connect as follows: customer master and delivery addresses define who we sell to and where. Orders reference both. Deliveries confirm each order. Invoices are issued against confirmed deliveries.

# %% [markdown]
# ## 3. The Gap
#
# > *Which required fields are missing or look problematic in our data?*
# > *Which tables are most relevant to check for each field?*
# > *Are there any fields that appear in multiple tables — and could they be inconsistent?*
#
# *In the data*

# %% [markdown]
# ## 4. The Impact
#
# > *How widespread do you expect the problem to be?*
# > *Which customers or transactions might be most at risk?*
# > *What would happen if TechDist GmbH had to send e-invoices today?*
#
# *(Write your plan here.)*

# %% [markdown]
# ## 5. Next Steps
#
# > *What would you recommend fixing first — and why?*
# > *Who in the business needs to be involved to fix each issue?*
# > *What would "good" look like after the fixes are applied?*
#
# *(Write your plan here.)*
