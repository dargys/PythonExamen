# %%
import pandas as pd

# %%
sales_rep = pd.read_csv("SalesRep.csv", sep=";")

# %%
sales_rep_clean = sales_rep.drop_duplicates()

# %%
sales_rep
# Out:
#               Manager  Manager Number  Sales Rep Number Sales Rep Name  \
# 0        Amanda Honda             104               103   Amalia Craig
# 1        Amanda Honda             104               176    Sheila Hein
# 2        Amanda Honda             104               104   Amanda Honda
# 3        Amanda Honda             104               112     Cart Lynch
# 4        Amanda Honda             104               103   Amalia Craig
# ...               ...             ...               ...            ...
# 29067  William Fisher             185               147   Kim Williams
# 29068  William Fisher             185               129   Edward Smith
# 29069  William Fisher             185               147   Kim Williams
# 29070  William Fisher             185               129   Edward Smith
# 29071  William Fisher             185               129   Edward Smith
#
#       Sales Rep Name2                                       Path
# ...

# %%
sales_rep_clean
# Out:
#                 Manager  Manager Number  Sales Rep Number  Sales Rep Name  \
# 0          Amanda Honda             104               103    Amalia Craig
# 1          Amanda Honda             104               176     Sheila Hein
# 2          Amanda Honda             104               104    Amanda Honda
# 3          Amanda Honda             104               112      Cart Lynch
# 21         Amanda Honda             104               159  Molly McKenzie
# ...                 ...             ...               ...             ...
# 26827      Stewart Wind             181               111  Carolyn Halmon
# 26829      Stewart Wind             181               181    Stewart Wind
# 28414  Viginia Mountain             184               127  Edward Laychak
# 28826    William Fisher             185               129    Edward Smith
# 28829    William Fisher             185               147    Kim Williams
#
#         Sales Rep Name2                                       Path
# ...

# %%
sales_rep_clean.to_csv("sales_rep_clean.csv", sep=";", index=False)
